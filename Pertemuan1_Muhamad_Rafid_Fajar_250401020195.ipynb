# %% [markdown]
# <a href="https://colab.research.google.com/github/rafidfajar/data-science-2026/blob/main/Pertemuan1_Muhamad_Rafid_Fajar_250401020195.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SEL 1: Output sederhana

# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %% [markdown]
# SEL 2: Variabel & tipe data

# %%
nama = "Muhamad Rafid Fajar" #string
angkatan = 2026              #integer
ipk = 3.67                   #float
aktif = True                 #boolean
print(f"Nama      : {nama}")
print(f"Angkatan  : {angkatan}")
print(f"IPK       : {ipk}")
print(f"Aktif     : {aktif}")
# Out:
# Nama      : Muhamad Rafid Fajar
# Angkatan  : 2026
# IPK       : 3.67
# Aktif     : True

# %% [markdown]
# SEL 3: List & perulangan

# %%
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
  print(f"  {i}. {tool}")
# Out:
#   1. Python
#   2. Colab
#   3. Jupyter
#   4. GitHub

# %% [markdown]
# SEL 4: Fungsi Python

# %%
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Muhamad Rafid Fajar","Informatika",2026))
# Out:
# Muhamad Rafid Fajar | Informatika | 2026
